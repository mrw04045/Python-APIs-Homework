# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#! pip install citipy

# %%
from datetime import date, datetime

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
#cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'Imperial'
#cities = ['ahipara', 'lavrentiya', 'hobart', 'ushuaia', 'kamenskoye', 'gandiaye', 'ribeira grande', 'katangli']

# Create empty lists to hold data
ls_temp = []
ls_wind_speed = []
ls_humidity = []
ls_lat = []
ls_cloudiness = []
ls_lon = []
ls_country = []
ls_date = []
ls_cities = []

print('''Beginning Data Retrieval     
-----------------------------''')
i = 1

# loop through cities list
for city in cities:
    
    try:      
        query_url = f"{base_url}units={units}&appid={api_key}&q={city}"
        response = requests.get(query_url).json()

        print(f"Processing Record {i} | {city}")

        # Define variables
        temp_max = response['main']['temp_max']
        wind_speed = response['wind']['speed']
        humidity = response['main']['humidity']
        lat = response['coord']['lat']
        cloudiness = response['clouds']['all']
        lon = response['coord']['lon']
        country = response['sys']['country']
        date = response['dt']

        # Append variables to corresponding lists
        ls_temp.append(temp_max)
        ls_wind_speed.append(wind_speed)
        ls_humidity.append(humidity)
        ls_lat.append(lat)
        ls_cloudiness.append(cloudiness)
        ls_lon.append(lon)
        ls_country.append(country)
        ls_date.append(date)
        ls_cities.append(city)

        i = i+1
    
    except:
        print("City not found. Skipping...")
        i = i+1
        
print('''-----------------------------
Data Retrieval Complete     
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | san patricio
# Processing Record 2 | kapaa
# Processing Record 3 | coquimbo
# Processing Record 4 | tromso
# Processing Record 5 | ilulissat
# Processing Record 6 | asyut
# Processing Record 7 | evanton
# Processing Record 8 | camabatela
# Processing Record 9 | kaele
# Processing Record 10 | busselton
# Processing Record 11 | jamestown
# Processing Record 12 | zabaykalsk
# Processing Record 13 | souillac
# Processing Record 14 | albany
# Processing Record 15 | lima
# Processing Record 16 | cabedelo
# Processing Record 17 | taolanaro
# City not found. Skipping...
# Processing Record 18 | clyde river
# Processing Record 19 | rusera
# Processing Record 20 | bethel
# Processing Record 21 | ahipara
# Processing Record 22 | saskylakh
# Processing Record 23 | kavieng
# Processing Record 24 | agadir
# Processing Record 25 | talnakh
# Processing Record 26 | narsaq
# Processing Record 27 | srednekolymsk
# Processing Record 28 | salalah
# Processing Record 29 | aklavik
# Processing Record 30 | puerto ayora
# Processing Record 31 | pangnirtung
# Processing Record 32 | amderma
# City not found. Skipping...
# Processing Record 33 | dukat
# Processing Record 34 | torbay
# Processing Record 35 | sorong
# Processing Record 36 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 | tuatapere
# Processing Record 38 | klyuchi
# Processing Record 39 | nikolskoye
# Processing Record 40 | mataura
# Processing Record 41 | hamilton
# Processing Record 42 | atuona
# Processing Record 43 | punta arenas
# Processing Record 44 | palmer
# Processing Record 45 | bogande
# Processing Record 46 | kamenka
# Processing Record 47 | rikitea
# Processing Record 48 | hermanus
# Processing Record 49 | xinan
# Processing Record 50 | grand river south east
# City not found. Skipping...
# Processing Record 51 | namatanai
# Processing Record 52 | trairi
# Processing Record 53 | beringovskiy
# Processing Record 54 | barentsburg
# City not found. Skipping...
# Processing Record 55 | sacosu turcesc
# Processing Record 56 | chokurdakh
# Processing Record 57 | chimoio
# Processing Record 58 | saint-joseph
# Processing Record 59 | ushuaia
# Processing Record 60 | georgetown
# Processing Record 61 | westport
# Processing Record 62 | coruripe
# Processing Record 63 | istisu
# Processing Record 64 | gomel
# City not found. Skipping...
# Processing Record 65 | vaini
# Processing Record 66 | nguiu
# City not found. Skipping...
# Processing Record 67 | pangody
# Processing Record 68 | esperance
# Processing Record 69 | cherskiy
# Processing Record 70 | carnarvon
# Processing Record 71 | jalu
# Processing Record 72 | baykit
# Processing Record 73 | hobart
# Processing Record 74 | iqaluit
# Processing Record 75 | hilo
# Processing Record 76 | douglas
# Processing Record 77 | vao
# Processing Record 78 | sitka
# Processing Record 79 | ribeira grande
# Processing Record 80 | lompoc
# Processing Record 81 | maumere
# Processing Record 82 | bairnsdale
# Processing Record 83 | linxia
# Processing Record 84 | kaitangata
# Processing Record 85 | bredasdorp
# Processing Record 86 | longyearbyen
# Processing Record 87 | lavrentiya
# Processing Record 88 | spring valley
# Processing Record 89 | bluff
# Processing Record 90 | yellowknife
# Processing Record 91 | nouakchott
# Processing Record 92 | barrow
# Processing Record 93 | dikson
# Processing Record 94 | hurghada
# City not found. Skipping...
# Processing Record 95 | maghama
# City not found. Skipping...
# Processing Record 96 | pasighat
# Processing Record 97 | castanos
# Processing Record 98 | rorvik
# Processing Record 99 | sao joao da barra
# Processing Record 100 | saldanha
# Processing Record 101 | palmdale
# Processing Record 102 | avera
# Processing Record 103 | parnamirim
# Processing Record 104 | port alfred
# Processing Record 105 | butaritari
# Processing Record 106 | upernavik
# Processing Record 107 | maniitsoq
# Processing Record 108 | new norfolk
# Processing Record 109 | pisco
# Processing Record 110 | provideniya
# Processing Record 111 | stupava
# Processing Record 112 | vaitupu
# City not found. Skipping...
# Processing Record 113 | nador
# Processing Record 114 | iranshahr
# Processing Record 115 | yingzhong
# City not found. Skipping...
# Processing Record 116 | dakar
# Processing Record 117 | cape town
# Processing Record 118 | pavilosta
# Processing Record 119 | mogadouro
# Processing Record 120 | attawapiskat
# City not found. Skipping...
# Processing Record 121 | yuli
# Processing Record 122 | qaanaaq
# Processing Record 123 | yashan
# Processing Record 124 | waterloo
# Processing Record 125 | tazovskiy
# Processing Record 126 | saint george
# Processing Record 127 | nantucket
# Processing Record 128 | chara
# Processing Record 129 | manokwari
# Processing Record 130 | vardo
# Processing Record 131 | krasnyy chikoy
# Processing Record 132 | eureka
# Processing Record 133 | chuy
# Processing Record 134 | tasiilaq
# Processing Record 135 | saint-philippe
# Processing Record 136 | rajanpur
# Processing Record 137 | klaksvik
# Processing Record 138 | batemans bay
# Processing Record 139 | fort saint john
# City not found. Skipping...
# Processing Record 140 | college
# Processing Record 141 | caravelas
# Processing Record 142 | guaruja
# Processing Record 143 | burayevo
# Processing Record 144 | nizhneyansk
# City not found. Skipping...
# Processing Record 145 | whitehorse
# Processing Record 146 | ucluelet
# Processing Record 147 | pekan
# Processing Record 148 | lindi
# Processing Record 149 | te anau
# Processing Record 150 | pemangkat
# City not found. Skipping...
# Processing Record 151 | williamsport
# Processing Record 152 | nemuro
# Processing Record 153 | faanui
# Processing Record 154 | qaqortoq
# Processing Record 155 | plettenberg bay
# Processing Record 156 | mantua
# Processing Record 157 | sao filipe
# Processing Record 158 | kodiak
# Processing Record 159 | keshan
# City not found. Skipping...
# Processing Record 160 | lamont
# Processing Record 161 | port blair
# Processing Record 162 | pucara
# Processing Record 163 | thompson
# Processing Record 164 | uusikaupunki
# Processing Record 165 | ardmore
# Processing Record 166 | guerrero negro
# Processing Record 167 | manggar
# Processing Record 168 | lebu
# Processing Record 169 | khatanga
# Processing Record 170 | katsuura
# Processing Record 171 | butembo
# Processing Record 172 | nanortalik
# Processing Record 173 | cidreira
# Processing Record 174 | sabla
# Processing Record 175 | harnosand
# Processing Record 176 | ridgecrest
# Processing Record 177 | ulaangom
# Processing Record 178 | flinders
# Processing Record 179 | haines junction
# Processing Record 180 | richards bay
# Processing Record 181 | egersund
# Processing Record 182 | englehart
# Processing Record 183 | ngukurr
# City not found. Skipping...
# Processing Record 184 | honiara
# Processing Record 185 | sentyabrskiy
# City not found. Skipping...
# Processing Record 186 | hofn
# Processing Record 187 | meyungs
# City not found. Skipping...
# Processing Record 188 | japura
# Processing Record 189 | darnah
# Processing Record 190 | chambery
# Processing Record 191 | coihaique
# Processing Record 192 | bonavista
# Processing Record 193 | dunedin
# Processing Record 194 | birjand
# Processing Record 195 | ishigaki
# Processing Record 196 | mehamn
# Processing Record 197 | bandarbeyla
# Processing Record 198 | esso
# Processing Record 199 | temaraia
# City not found. Skipping...
# Processing Record 200 | ixtapa
# Processing Record 201 | tiksi
# Processing Record 202 | vila
# Processing Record 203 | dubai
# Processing Record 204 | belaya gora
# Processing Record 205 | nyaunglebin
# Processing Record 206 | sataua
# City not found. Skipping...
# Processing Record 207 | pevek
# Processing Record 208 | arraial do cabo
# Processing Record 209 | saint-pierre
# Processing Record 210 | namibe
# Processing Record 211 | nagai
# Processing Record 212 | katobu
# Processing Record 213 | geraldton
# Processing Record 214 | gushikawa
# Processing Record 215 | freeport
# Processing Record 216 | brownsburg
# Processing Record 217 | ornskoldsvik
# Processing Record 218 | geresk
# City not found. Skipping...
# Processing Record 219 | kuna
# Processing Record 220 | gat
# Processing Record 221 | lulea
# Processing Record 222 | oyama
# Processing Record 223 | paita
# Processing Record 224 | mmathubudukwane
# Processing Record 225 | mys shmidta
# City not found. Skipping...
# Processing Record 226 | olafsvik
# City not found. Skipping...
# Processing Record 227 | tuktoyaktuk
# Processing Record 228 | fairbanks
# Processing Record 229 | alta floresta
# Processing Record 230 | kisangani
# Processing Record 231 | mansehra
# Processing Record 232 | hasaki
# Processing Record 233 | mar del plata
# Processing Record 234 | puerto penasco
# Processing Record 235 | tumannyy
# City not found. Skipping...
# Processing Record 236 | walvis bay
# Processing Record 237 | bambous virieux
# Processing Record 238 | diego de almagro
# Processing Record 239 | escanaba
# Processing Record 240 | sao miguel do araguaia
# Processing Record 241 | ouadda
# Processing Record 242 | sinkat
# City not found. Skipping...
# Processing Record 243 | castro
# Processing Record 244 | tawau
# Processing Record 245 | jadu
# Processing Record 246 | girne
# City not found. Skipping...
# Processing Record 247 | haukipudas
# Processing Record 248 | hami
# Processing Record 249 | san quintin
# Processing Record 250 | taoudenni
# Processing Record 251 | voi
# Processing Record 252 | ponta do sol
# Processing Record 253 | wuchi
# Processing Record 254 | tiznit
# Processing Record 255 | umm kaddadah
# Processing Record 256 | kapuskasing
# Processing Record 257 | gimli
# Processing Record 258 | kysyl-syr
# Processing Record 259 | rauma
# Processing Record 260 | noumea
# Processing Record 261 | mongu
# Processing Record 262 | kazalinsk
# City not found. Skipping...
# Processing Record 263 | olavarria
# Processing Record 264 | lata
# Processing Record 265 | cuajinicuilapa
# Processing Record 266 | macau
# Processing Record 267 | phetchabun
# Processing Record 268 | east london
# Processing Record 269 | teya
# Processing Record 270 | luderitz
# Processing Record 271 | marsh harbour
# Processing Record 272 | port elizabeth
# Processing Record 273 | nome
# Processing Record 274 | tilichiki
# Processing Record 275 | abengourou
# Processing Record 276 | teknaf
# Processing Record 277 | anar darreh
# City not found. Skipping...
# Processing Record 278 | ponta delgada
# Processing Record 279 | severnyy
# City not found. Skipping...
# Processing Record 280 | noyon
# Processing Record 281 | kargasok
# Processing Record 282 | yacuiba
# Processing Record 283 | valparaiso
# Processing Record 284 | dingle
# Processing Record 285 | jiuquan
# Processing Record 286 | sangar
# Processing Record 287 | borovoy
# Processing Record 288 | deputatskiy
# Processing Record 289 | comodoro rivadavia
# Processing Record 290 | nyurba
# Processing Record 291 | severo-kurilsk
# Processing Record 292 | mahebourg
# Processing Record 293 | lagoa
# Processing Record 294 | yarmouth
# Processing Record 295 | port lincoln
# Processing Record 296 | victoria
# Processing Record 297 | pangoa
# Processing Record 298 | luganville
# Processing Record 299 | wasilla
# Processing Record 300 | avarua
# Processing Record 301 | lokosovo
# Processing Record 302 | rio gallegos
# Processing Record 303 | luebo
# Processing Record 304 | botou
# Processing Record 305 | mezen
# Processing Record 306 | hithadhoo
# Processing Record 307 | bela
# Processing Record 308 | stafford
# Processing Record 309 | kloulklubed
# Processing Record 310 | acapulco
# Processing Record 311 | havre-saint-pierre
# Processing Record 312 | mount isa
# Processing Record 313 | bacuit
# City not found. Skipping...
# Processing Record 314 | notse
# Processing Record 315 | mahibadhoo
# Processing Record 316 | codrington
# Processing Record 317 | mount gambier
# Processing Record 318 | fortuna
# Processing Record 319 | kholodnyy
# Processing Record 320 | moose factory
# Processing Record 321 | luanda
# Processing Record 322 | cayenne
# Processing Record 323 | husavik
# Processing Record 324 | billings
# Processing Record 325 | abu dhabi
# Processing Record 326 | kangundo
# Processing Record 327 | ayan
# Processing Record 328 | kodinsk
# Processing Record 329 | louth
# Processing Record 330 | leningradskiy
# Processing Record 331 | tanout
# Processing Record 332 | ostrovnoy
# Processing Record 333 | opuwo
# Processing Record 334 | kota belud
# Processing Record 335 | turtas
# Processing Record 336 | asau
# City not found. Skipping...
# Processing Record 337 | praia
# Processing Record 338 | yangmei
# Processing Record 339 | belushya guba
# City not found. Skipping...
# Processing Record 340 | itarema
# Processing Record 341 | bud
# Processing Record 342 | coahuayana
# Processing Record 343 | teguise
# Processing Record 344 | tsihombe
# City not found. Skipping...
# Processing Record 345 | shkotovo-26
# City not found. Skipping...
# Processing Record 346 | norman wells
# Processing Record 347 | balbalan
# Processing Record 348 | oriximina
# Processing Record 349 | vostok
# Processing Record 350 | svetlyy
# City not found. Skipping...
# Processing Record 351 | trincomalee
# Processing Record 352 | hailin
# Processing Record 353 | bathsheba
# Processing Record 354 | luzhou
# Processing Record 355 | rungata
# City not found. Skipping...
# Processing Record 356 | tautira
# Processing Record 357 | matara
# Processing Record 358 | olinda
# Processing Record 359 | oga
# Processing Record 360 | malmesbury
# Processing Record 361 | derzhavinsk
# Processing Record 362 | dongsheng
# Processing Record 363 | lasa
# Processing Record 364 | guangyuan
# Processing Record 365 | airai
# Processing Record 366 | eskisehir
# Processing Record 367 | tsiroanomandidy
# Processing Record 368 | talcahuano
# Processing Record 369 | mogadishu
# Processing Record 370 | palabuhanratu
# City not found. Skipping...
# Processing Record 371 | vila franca do campo
# Processing Record 372 | kendari
# Processing Record 373 | feijo
# Processing Record 374 | aripuana
# Processing Record 375 | samarai
# Processing Record 376 | jazzin
# City not found. Skipping...
# Processing Record 377 | mossoro
# Processing Record 378 | puerto escondido
# Processing Record 379 | tiassale
# Processing Record 380 | taltal
# Processing Record 381 | pacific grove
# Processing Record 382 | kyshtovka
# Processing Record 383 | kalmunai
# Processing Record 384 | santa cruz
# Processing Record 385 | carupano
# Processing Record 386 | san cristobal
# Processing Record 387 | yian
# City not found. Skipping...
# Processing Record 388 | meulaboh
# Processing Record 389 | ariquemes
# Processing Record 390 | canaries
# City not found. Skipping...
# Processing Record 391 | kuala terengganu
# Processing Record 392 | tessalit
# Processing Record 393 | aniva
# Processing Record 394 | pontianak
# Processing Record 395 | taburi
# City not found. Skipping...
# Processing Record 396 | galiwinku
# City not found. Skipping...
# Processing Record 397 | kruisfontein
# Processing Record 398 | corinto
# Processing Record 399 | sibul
# Processing Record 400 | ugoofaaru
# Processing Record 401 | samana
# Processing Record 402 | kerouane
# Processing Record 403 | rognan
# Processing Record 404 | grindavik
# Processing Record 405 | slave lake
# Processing Record 406 | paiho
# City not found. Skipping...
# Processing Record 407 | bargal
# City not found. Skipping...
# Processing Record 408 | myaundzha
# Processing Record 409 | kudahuvadhoo
# Processing Record 410 | itaituba
# Processing Record 411 | alihe
# Processing Record 412 | marcona
# City not found. Skipping...
# Processing Record 413 | elko
# Processing Record 414 | tynda
# Processing Record 415 | hirara
# Processing Record 416 | tolaga bay
# Processing Record 417 | touros
# Processing Record 418 | hervey bay
# Processing Record 419 | cabrobo
# Processing Record 420 | inirida
# Processing Record 421 | gatesville
# Processing Record 422 | isangel
# Processing Record 423 | kutum
# Processing Record 424 | mayo
# Processing Record 425 | mandasa
# Processing Record 426 | yulara
# Processing Record 427 | sassandra
# Processing Record 428 | bichena
# Processing Record 429 | san gabriel
# Processing Record 430 | takoradi
# Processing Record 431 | hunchun
# Processing Record 432 | tura
# Processing Record 433 | lazaro cardenas
# Processing Record 434 | brae
# Processing Record 435 | price
# Processing Record 436 | portland
# Processing Record 437 | lolodorf
# Processing Record 438 | port-gentil
# Processing Record 439 | belmonte
# Processing Record 440 | cabo san lucas
# Processing Record 441 | beira
# Processing Record 442 | chilca
# Processing Record 443 | sabalgarh
# Processing Record 444 | zhigansk
# Processing Record 445 | ratnapura
# Processing Record 446 | rancagua
# Processing Record 447 | revelstoke
# Processing Record 448 | yar-sale
# Processing Record 449 | severo-yeniseyskiy
# Processing Record 450 | north branch
# Processing Record 451 | poum
# Processing Record 452 | navapur
# City not found. Skipping...
# Processing Record 453 | lalomanu
# City not found. Skipping...
# Processing Record 454 | mangaratiba
# Processing Record 455 | vannes
# Processing Record 456 | brindisi
# Processing Record 457 | onega
# Processing Record 458 | kholtoson
# Processing Record 459 | toma
# Processing Record 460 | lodja
# Processing Record 461 | zernograd
# Processing Record 462 | ruatoria
# City not found. Skipping...
# Processing Record 463 | mrirt
# City not found. Skipping...
# Processing Record 464 | chahuites
# Processing Record 465 | moba
# Processing Record 466 | hualmay
# Processing Record 467 | deoria
# Processing Record 468 | karaton
# Processing Record 469 | sistranda
# Processing Record 470 | tiarei
# Processing Record 471 | berlevag
# Processing Record 472 | payo
# Processing Record 473 | skierniewice
# Processing Record 474 | mbala
# Processing Record 475 | constitucion
# Processing Record 476 | turukhansk
# Processing Record 477 | wewak
# Processing Record 478 | siwan
# Processing Record 479 | inderborskiy
# City not found. Skipping...
# Processing Record 480 | mme
# City not found. Skipping...
# Processing Record 481 | kommunisticheskiy
# Processing Record 482 | nouadhibou
# Processing Record 483 | abeche
# Processing Record 484 | vestmannaeyjar
# Processing Record 485 | namwala
# Processing Record 486 | viligili
# City not found. Skipping...
# Processing Record 487 | tarbagatay
# Processing Record 488 | balkhash
# Processing Record 489 | great falls
# Processing Record 490 | ambilobe
# Processing Record 491 | tabiauea
# City not found. Skipping...
# Processing Record 492 | valley city
# Processing Record 493 | pokhara
# Processing Record 494 | uarini
# Processing Record 495 | ous
# Processing Record 496 | skjervoy
# Processing Record 497 | van
# Processing Record 498 | fredonia
# Processing Record 499 | amahai
# Processing Record 500 | caraballeda
# Processing Record 501 | ancud
# Processing Record 502 | kuminskiy
# Processing Record 503 | basyanovskiy
# City not found. Skipping...
# Processing Record 504 | karasjok
# Processing Record 505 | quatre cocos
# Processing Record 506 | maceio
# Processing Record 507 | kargil
# Processing Record 508 | saint-georges
# Processing Record 509 | samusu
# City not found. Skipping...
# Processing Record 510 | lolua
# City not found. Skipping...
# Processing Record 511 | kashi
# City not found. Skipping...
# Processing Record 512 | ahuimanu
# Processing Record 513 | port augusta
# Processing Record 514 | saint-augustin
# Processing Record 515 | nelson bay
# Processing Record 516 | watsa
# Processing Record 517 | aden
# Processing Record 518 | bengkulu
# City not found. Skipping...
# Processing Record 519 | vanimo
# Processing Record 520 | high level
# Processing Record 521 | the valley
# Processing Record 522 | bani
# Processing Record 523 | quchan
# Processing Record 524 | inuvik
# Processing Record 525 | hay river
# Processing Record 526 | egvekinot
# Processing Record 527 | viraganur
# Processing Record 528 | akropong
# Processing Record 529 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 530 | alyangula
# Processing Record 531 | archdale
# Processing Record 532 | cairns
# Processing Record 533 | plymouth
# Processing Record 534 | zhangjiakou
# Processing Record 535 | havelock
# Processing Record 536 | beisfjord
# Processing Record 537 | ketchikan
# Processing Record 538 | parabel
# Processing Record 539 | kupang
# Processing Record 540 | rodeo
# Processing Record 541 | ustrzyki dolne
# Processing Record 542 | araguaina
# Processing Record 543 | chegdomyn
# Processing Record 544 | verkhoyansk
# Processing Record 545 | tierra blanca
# Processing Record 546 | turtkul
# City not found. Skipping...
# Processing Record 547 | sainte-maxime
# Processing Record 548 | vaitape
# Processing Record 549 | beloha
# Processing Record 550 | oppdal
# Processing Record 551 | sorvag
# City not found. Skipping...
# Processing Record 552 | zyryanka
# Processing Record 553 | abha
# Processing Record 554 | xinxiang
# Processing Record 555 | saleaula
# City not found. Skipping...
# Processing Record 556 | novobataysk
# Processing Record 557 | promyshlennaya
# Processing Record 558 | edd
# Processing Record 559 | puerto narino
# Processing Record 560 | clovis
# Processing Record 561 | sobolevo
# Processing Record 562 | pihuamo
# Processing Record 563 | haibowan
# City not found. Skipping...
# Processing Record 564 | sovetskoye
# Processing Record 565 | sumbe
# Processing Record 566 | halalo
# City not found. Skipping...
# Processing Record 567 | lubbock
# Processing Record 568 | linfen
# Processing Record 569 | shaartuz
# City not found. Skipping...
# Processing Record 570 | mandalgovi
# Processing Record 571 | miyako
# Processing Record 572 | plyussa
# Processing Record 573 | krasnyy oktyabr
# Processing Record 574 | mandan
# Processing Record 575 | angelholm
# City not found. Skipping...
# Processing Record 576 | lebedinyy
# Processing Record 577 | sidney
# Processing Record 578 | isiro
# Processing Record 579 | daosa
# City not found. Skipping...
# Processing Record 580 | kavaratti
# Processing Record 581 | athens
# Processing Record 582 | krasnovishersk
# Processing Record 583 | antsohihy
# Processing Record 584 | skalistyy
# City not found. Skipping...
# Processing Record 585 | tonk
# Processing Record 586 | tobol
# Processing Record 587 | telixtlahuaca
# City not found. Skipping...
# Processing Record 588 | blagoveshchensk
# Processing Record 589 | raudeberg
# Processing Record 590 | kure
# Processing Record 591 | rudbar
# City not found. Skipping...
# Processing Record 592 | ouesso
# Processing Record 593 | kaniama
# Processing Record 594 | sabang
# Processing Record 595 | sergeyevka
# Processing Record 596 | tateyama
# Processing Record 597 | borovichi
# Processing Record 598 | vinh
# Processing Record 599 | jaunjelgava
# Processing Record 600 | wolmaranstad
# City not found. Skipping...
# Processing Record 601 | casper
# Processing Record 602 | kongolo
# Processing Record 603 | sinjai
# Processing Record 604 | boulder city
# Processing Record 605 | ulagan
# Processing Record 606 | taree
# Processing Record 607 | pangkalanbuun
# Processing Record 608 | punta de bombon
# Processing Record 609 | grootfontein
# Processing Record 610 | dawlatabad
# Processing Record 611 | ljungby
# Processing Record 612 | puerto leguizamo
# Processing Record 613 | sinnamary
# Processing Record 614 | kieta
# Processing Record 615 | kiunga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe
city_data = pd.DataFrame({'City': ls_cities,
                          'Cloudiness': ls_cloudiness,
                          'Country': ls_country,
                          'Humidity': ls_humidity,
                          'Date': ls_date,
                          'Lat': ls_lat,
                          'Lng': ls_lon,
                          'Max Temp': ls_temp,
                          'Wind Speed': ls_wind_speed})

# Export the city data into a .csv file
city_data.to_csv(output_data_file)

# Display the DataFrame
city_data.head()
# Out:
#            City  Cloudiness Country  Humidity        Date    Lat     Lng  \
# 0  san patricio          57      PY        96  1558330339 -26.98  -56.83
# 1         kapaa          90      US        78  1558330131  22.08 -159.32
# 2      coquimbo          90      CL        93  1558330348 -29.95  -71.34
# 3        tromso           0      NO        70  1558330382  69.65   18.96
# 4     ilulissat          12      GL        92  1558330356  69.22  -51.10
#
#    Max Temp  Wind Speed
# 0     64.54        4.83
# 1     80.60       17.22
# 2     53.60        4.70
# 3     53.60        5.82
# 4     30.20        2.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# # https://docs.python.org/2/library/datetime.html#datetime.datetime.fromtimestamp

# month = datetime.utcfromtimestamp(city_data['Date'][0]).month
# day = datetime.utcfromtimestamp(city_data['Date'][0]).day
# year = (datetime.utcfromtimestamp(city_data['Date'][0]).year) - 2000
# date = f"{month}/{day}/{year}"

# %%
month = datetime.now().month
day = datetime.now().day
year = (datetime.now().year) - 2000
date = f"{month}/{day}/{year}"

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
ax = city_data.plot(kind='scatter', x='Lat', y='Max Temp', color='blue', edgecolor='black')
ax.set_title(f'City Latitude vs. Max Temperature ({date})')
ax.set_xlabel('Latitude')
ax.set_ylabel('Max Temperature (F)')
ax.grid(color='white')
# https://stackoverflow.com/questions/1726391/matplotlib-draw-grid-lines-behind-other-graph-elements
ax.set_axisbelow(True)
#https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.set_facecolor.html#matplotlib.axes.Axes.set_facecolor
ax.set_facecolor('lavender')

top_lim = city_data['Max Temp'].max()
bottom_lim = city_data['Max Temp'].min()

ax.set_ylim(bottom_lim -15, top_lim +15)
ax.set_xlim(-80, 100)
plt.savefig('output_data/temp.png', dpi=150)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax = city_data.plot(kind='scatter', x='Lat', y='Humidity', color='blue', edgecolor='black')
ax.set_title(f'City Latitude vs. Humidity ({date})')
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity (%)')
ax.grid(color='white')
ax.set_axisbelow(True)
ax.set_facecolor('lavender')
ax.set_ylim(-20, 120)
ax.set_xlim(-80, 100)
plt.savefig('output_data/humidity.png', dpi=150)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax = city_data.plot(kind='scatter', x='Lat', y='Cloudiness', color='blue', edgecolor='black')
ax.set_title(f'City Latitude vs. Cloudiness ({date})')
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness (%)')
ax.grid(color='white')
ax.set_axisbelow(True)
ax.set_facecolor('lavender')
ax.set_ylim(-20, 120)
ax.set_xlim(-80, 100)
plt.savefig('output_data/cloudiness.png', dpi=150)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax = city_data.plot(kind='scatter', x='Lat', y='Wind Speed', color='blue', edgecolor='black')
ax.set_title(f'City Latitude vs. Wind Speed ({date})')
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed (mph)')
ax.grid(color='white')
ax.set_axisbelow(True)
ax.set_facecolor('lavender')

top_lim = city_data['Wind Speed'].max()
ax.set_ylim(-5, top_lim +5)
ax.set_xlim(-80, 100)
plt.savefig('output_data/wind_speed.png', dpi=150)
plt.show()
